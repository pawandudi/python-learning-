# %%
print("hello pawan")
# Out:
# hello pawan

# %%
# we can also use how and other functions

# %%
# we can also use how and other functions

# %%
# we can also use how and other functions

# %%
import pandas as pd
import numpy as np

# %%
data_rows = [
    ['John Smith', 50000, 25],
    ['Jane Doe', 60000, 30],
    ['Bob Johnson', 55000, 28]
]

# %%
d=pd.DataFrame(data_rows,columns=['Name', 'Salary', 'Age'])

# %%
d
# Out:
#           Name  Salary  Age
# 0   John Smith   50000   25
# 1     Jane Doe   60000   30
# 2  Bob Johnson   55000   28

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['NYC', 'LA', 'Chicago']
}

# %%
v = pd.DataFrame(data)

# %%
v
# Out:
#       Name  Age     City
# 0    Alice   25      NYC
# 1      Bob   30       LA
# 2  Charlie   35  Chicago

# %%
v[['Name','Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
v["exp"]=["3","2","4"]

# %%
# axis= 1  mean found from up
# axis=0 mean found from left
# use (inplace = true) to permanentky change

# %%
v.drop("Age", axis = 1  )
# Out:
#       Name     City exp
# 0    Alice      NYC   3
# 1      Bob       LA   2
# 2  Charlie  Chicago   4

# %%
v
# Out:
#       Name  Age     City exp
# 0    Alice   25      NYC   3
# 1      Bob   30       LA   2
# 2  Charlie   35  Chicago   4

# %%
v.loc[[0,1]][["Age","City"]]
# Out:
#    Age City
# 0   25  NYC
# 1   30   LA

# %%
v[(v["Age"] > 25) & (v["City"] == 'LA')]
# Out:
#   Name  Age City exp
# 1  Bob   30   LA   2

# %%
data = {
    'Name': ['Alice', 'Bob', None, 'David', 'Eve'],
    'Age': [25, np.nan, 35, 28, np.nan],
    'City': ['NYC', 'LA', np.nan, None, 'Boston']
}

# %%
c = pd.DataFrame(data)

# %%
c
# Out:
#     Name   Age    City
# 0  Alice  25.0     NYC
# 1    Bob   NaN      LA
# 2   None  35.0     NaN
# 3  David  28.0    None
# 4    Eve   NaN  Boston

# %%
c.isna().sum()
# Out:
# Name    1
# Age     2
# City    2
# dtype: int64

# %%
c.isna()
# Out:
#     Name    Age   City
# 0  False  False  False
# 1  False   True  False
# 2   True  False   True
# 3  False  False   True
# 4  False   True  False

# %%
c.isna().any()
# Out:
# Name    True
# Age     True
# City    True
# dtype: bool

# %%
c.dropna()
# dropna mean chenk in which row is no null value
# Out:
#     Name   Age City
# 0  Alice  25.0  NYC

# %%
c.dropna(thresh=2)
# thresh at lat 2 non null value
# Out:
#     Name   Age    City
# 0  Alice  25.0     NYC
# 1    Bob   NaN      LA
# 3  David  28.0    None
# 4    Eve   NaN  Boston

# %%
c.fillna(0)
# Out:
#     Name   Age    City
# 0  Alice  25.0     NYC
# 1    Bob   0.0      LA
# 2      0  35.0       0
# 3  David  28.0       0
# 4    Eve   0.0  Boston

# %%
valu = {"Name":2,"Age":3,"City":4}
c.fillna(valu)
# Out:
#     Name   Age    City
# 0  Alice  25.0     NYC
# 1    Bob   3.0      LA
# 2      2  35.0       4
# 3  David  28.0       4
# 4    Eve   3.0  Boston

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'City': ['NYC', 'LA', 'Chicago', 'Houston']
})

# DataFrame 2
df2 = pd.DataFrame({
    # 'ID': [3, 4, 5, 6],
    'Salary': [70000, 80000, 65000, 90000],
    'Experience': [5, 8, 3, 10]
})

# %%
pd.merge(df1,df2)
# Out:
#    ID     Name     City  Salary  Experience
# 0   3  Charlie  Chicago   70000           5
# 1   4    David  Houston   80000           8

# %%
pd.merge(df1,df2,on= 'ID',how ='inner')
# Out:
#    ID     Name     City  Salary  Experience
# 0   3  Charlie  Chicago   70000           5
# 1   4    David  Houston   80000           8

# %%
pd.merge(df1,df2,on= 'ID',how ='outer')
# Out:
#    ID     Name     City   Salary  Experience
# 0   1    Alice      NYC      NaN         NaN
# 1   2      Bob       LA      NaN         NaN
# 2   3  Charlie  Chicago  70000.0         5.0
# 3   4    David  Houston  80000.0         8.0
# 4   5      NaN      NaN  65000.0         3.0
# 5   6      NaN      NaN  90000.0        10.0

# %%
pd.merge(df1,df2,on= 'ID',how ='left')
# Out:
#    ID     Name     City   Salary  Experience
# 0   1    Alice      NYC      NaN         NaN
# 1   2      Bob       LA      NaN         NaN
# 2   3  Charlie  Chicago  70000.0         5.0
# 3   4    David  Houston  80000.0         8.0

# %%
pd.merge(df1,df2,on= 'ID',how ='right')
# Out:
#    ID     Name     City  Salary  Experience
# 0   3  Charlie  Chicago   70000           5
# 1   4    David  Houston   80000           8
# 2   5      NaN      NaN   65000           3
# 3   6      NaN      NaN   90000          10

# %%
pd.concat([df1,df2])
# we can also use axis
# Out:
#    ID     Name     City   Salary  Experience
# 0   1    Alice      NYC      NaN         NaN
# 1   2      Bob       LA      NaN         NaN
# 2   3  Charlie  Chicago      NaN         NaN
# 3   4    David  Houston      NaN         NaN
# 0   3      NaN      NaN  70000.0         5.0
# 1   4      NaN      NaN  80000.0         8.0
# 2   5      NaN      NaN  65000.0         3.0
# 3   6      NaN      NaN  90000.0        10.0

# %%
# pd.concat([df1,df2],axis=1)

# %%
df1.join(df2)
# Out:
#    ID     Name     City  Salary  Experience
# 0   1    Alice      NYC   70000           5
# 1   2      Bob       LA   80000           8
# 2   3  Charlie  Chicago   65000           3
# 3   4    David  Houston   90000          10

# %%
df2.join(df1)
# Out:
#    Salary  Experience  ID     Name     City
# 0   70000           5   1    Alice      NYC
# 1   80000           8   2      Bob       LA
# 2   65000           3   3  Charlie  Chicago
# 3   90000          10   4    David  Houston

# %%
import os
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df3=({
    'Team': ['A', 'A', 'B', 'B'],
    'Points': [10, 20, 30, 40],
    'Assists': [5, 7, 8, 6]
})
m = pd.DataFrame(df3)
m
# Out:
#   Team  Points  Assists
# 0    A      10        5
# 1    A      20        7
# 2    B      30        8
# 3    B      40        6

# %%
cat = m.groupby('Team')
cat
for i, v in cat:
    print(i)
    print(v)
# Out:
# A
#   Team  Points  Assists
# 0    A      10        5
# 1    A      20        7
# B
#   Team  Points  Assists
# 2    B      30        8
# 3    B      40        6

# %%
cat = m.groupby('Team')['Points'].sum()
cat
# Out:
# Team
# A    30
# B    70
# Name: Points, dtype: int64

# %%
# you can add more near team
#

# %%
cat['points'].mean()

# %%
cat['point'].agg(['mean','min','max','median','sum','count','std'])
